# %%
import pandas as pd

# %%
data = {
    "Yil" : [2021,2020,2019,2018,2017,2016,2015,2010],
    "Aholi soni" : [33.9,33.5,32.9,32.5,31.9,31.4,30.9,28.5],
    "Temp" : [1.54,1.44,1.39,1.32,1.29,1.26,1.24,0.24],
}

# %%
data
# Out:
# {'Yil': [2021, 2020, 2019, 2018, 2017, 2016, 2015, 2010],
#  'Aholi soni': [33.9, 33.5, 32.9, 32.5, 31.9, 31.4, 30.9, 28.5],
#  'Temp': [1.54, 1.44, 1.39, 1.32, 1.29, 1.26, 1.24, 0.24]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.44
# 2  2019        32.9  1.39
# 3  2018        32.5  1.32
# 4  2017        31.9  1.29
# 5  2016        31.4  1.26
# 6  2015        30.9  1.24
# 7  2010        28.5  0.24

# %%
df.shape
# Out:
# (8, 3)

# %%
df.head()
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.44
# 2  2019        32.9  1.39
# 3  2018        32.5  1.32
# 4  2017        31.9  1.29

# %%
df.head(3)
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.44
# 2  2019        32.9  1.39

# %%
df = pd.DataFrame(data, columns=["Yil","Temp","Aholi soni", "yangi"])

# %%
df
# Out:
#     Yil  Temp  Aholi soni yangi
# 0  2021  1.54        33.9   NaN
# 1  2020  1.44        33.5   NaN
# 2  2019  1.39        32.9   NaN
# 3  2018  1.32        32.5   NaN
# 4  2017  1.29        31.9   NaN
# 5  2016  1.26        31.4   NaN
# 6  2015  1.24        30.9   NaN
# 7  2010  0.24        28.5   NaN

# %%
df = pd.DataFrame(data, columns=["Yil","Temp","Aholi soni", "yangi"], index=[5,10,15,20,25,30,35,40])

# %%
df
# Out:
#      Yil  Temp  Aholi soni yangi
# 5   2021  1.54        33.9   NaN
# 10  2020  1.44        33.5   NaN
# 15  2019  1.39        32.9   NaN
# 20  2018  1.32        32.5   NaN
# 25  2017  1.29        31.9   NaN
# 30  2016  1.26        31.4   NaN
# 35  2015  1.24        30.9   NaN
# 40  2010  0.24        28.5   NaN

# %%
aholi = df["Aholi soni"]

# %%
aholi
# Out:
# 5     33.9
# 10    33.5
# 15    32.9
# 20    32.5
# 25    31.9
# 30    31.4
# 35    30.9
# 40    28.5
# Name: Aholi soni, dtype: float64

# %%
df.yangi = 0

# %%
df
# Out:
#      Yil  Temp  Aholi soni  yangi
# 5   2021  1.54        33.9      0
# 10  2020  1.44        33.5      0
# 15  2019  1.39        32.9      0
# 20  2018  1.32        32.5      0
# 25  2017  1.29        31.9      0
# 30  2016  1.26        31.4      0
# 35  2015  1.24        30.9      0
# 40  2010  0.24        28.5      0

# %%
df.shape
# Out:
# (8, 4)

# %%
df.yangi = pd.Series([1500, 1600, 1240, 874], index=[5,10,15,20])

# %%
df
# Out:
#      Yil  Temp  Aholi soni   yangi
# 5   2021  1.54        33.9  1500.0
# 10  2020  1.44        33.5  1600.0
# 15  2019  1.39        32.9  1240.0
# 20  2018  1.32        32.5   874.0
# 25  2017  1.29        31.9     NaN
# 30  2016  1.26        31.4     NaN
# 35  2015  1.24        30.9     NaN
# 40  2010  0.24        28.5     NaN

# %%
val = [1500, 1600, 1240, 874, 500, 600, 798,120]

# %%
df.yangi = val

# %%
df
# Out:
#      Yil  Temp  Aholi soni  yangi
# 5   2021  1.54        33.9   1500
# 10  2020  1.44        33.5   1600
# 15  2019  1.39        32.9   1240
# 20  2018  1.32        32.5    874
# 25  2017  1.29        31.9    500
# 30  2016  1.26        31.4    600
# 35  2015  1.24        30.9    798
# 40  2010  0.24        28.5    120

# %%
df['700+'] = df.yangi>700

# %%
df
# Out:
#      Yil  Temp  Aholi soni  yangi   700+
# 5   2021  1.54        33.9   1500   True
# 10  2020  1.44        33.5   1600   True
# 15  2019  1.39        32.9   1240   True
# 20  2018  1.32        32.5    874   True
# 25  2017  1.29        31.9    500  False
# 30  2016  1.26        31.4    600  False
# 35  2015  1.24        30.9    798   True
# 40  2010  0.24        28.5    120  False

# %%
del df['700+']

# %%
df
# Out:
#      Yil  Temp  Aholi soni  yangi
# 5   2021  1.54        33.9   1500
# 10  2020  1.44        33.5   1600
# 15  2019  1.39        32.9   1240
# 20  2018  1.32        32.5    874
# 25  2017  1.29        31.9    500
# 30  2016  1.26        31.4    600
# 35  2015  1.24        30.9    798
# 40  2010  0.24        28.5    120
