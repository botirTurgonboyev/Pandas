# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/usa_cars.csv", index_col=0)

# %%
df.head()
# Out:
#    price      brand    model  year   title_status  mileage   color  \
# 0   6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1   2899       ford       se  2011  clean vehicle   190552  silver
# 2   5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3  25000       ford     door  2014  clean vehicle    64146    blue
# 4  27700  chevrolet     1500  2018  clean vehicle     6654     red
#
#                    vin        lot       state country      condition
# 0    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
df.shape
# Out:
# (2499, 12)

# %%
df.head(6)
# Out:
#    price      brand    model  year   title_status  mileage   color  \
# 0   6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1   2899       ford       se  2011  clean vehicle   190552  silver
# 2   5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3  25000       ford     door  2014  clean vehicle    64146    blue
# 4  27700  chevrolet     1500  2018  clean vehicle     6654     red
# 5   5700      dodge      mpv  2018  clean vehicle    45561   white
#
#                    vin        lot       state country      condition
# 0    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4    3gcpcrec2jg473991  167763266     florida     usa  22 hours left
# 5    2c4rdgeg9jr237989  167655771       texas     usa    2 days left

# %%
df.tail(6)
# Out:
#       price   brand  model  year   title_status  mileage   color  \
# 2493   9200  nissan  versa  2018  clean vehicle    33027   black
# 2494   7800  nissan  versa  2019  clean vehicle    23609     red
# 2495   9200  nissan  versa  2018  clean vehicle    34553  silver
# 2496   9200  nissan  versa  2018  clean vehicle    31594  silver
# 2497   9200  nissan  versa  2018  clean vehicle    32557   black
# 2498   9200  nissan  versa  2018  clean vehicle    31371  silver
#
#                       vin        lot       state country      condition
# 2493    3n1cn7ap0jl883768  167762224     florida     usa  21 hours left
# 2494    3n1cn7ap9kl880319  167722715  california     usa    1 days left
# 2495    3n1cn7ap5jl884088  167762225     florida     usa  21 hours left
# 2496    3n1cn7ap9jl884191  167762226     florida     usa  21 hours left
# 2497    3n1cn7ap3jl883263  167762227     florida     usa    2 days left
# 2498    3n1cn7ap4jl884311  167762228     florida     usa  21 hours left

# %%
df.sort_values('year')
# Out:
#       price      brand    model  year       title_status  mileage       color  \
# 32    29800  chevrolet   camaro  1973      clean vehicle    46226         red
# 405      25       ford     door  1984  salvage insurance    41577       white
# 545       0        gmc     door  1993  salvage insurance        0  light blue
# 322       0       ford  chassis  1994  salvage insurance        0       green
# 362      25       ford   pickup  1994  salvage insurance   206162       white
# ...     ...        ...      ...   ...                ...      ...         ...
# 1676  23400       ford   fusion  2020      clean vehicle     2452        gray
# 1642  20600       ford   fusion  2020      clean vehicle    17858       black
# 206      25  chevrolet   vehicl  2020  salvage insurance     7232       black
# 1640  27000       ford  mustang  2020      clean vehicle    12748         red
# 1638  20000       ford   fusion  2020      clean vehicle    23984      silver
#
# ...

# %%
df.sort_values(by='year')
# Out:
#       price      brand    model  year       title_status  mileage       color  \
# 32    29800  chevrolet   camaro  1973      clean vehicle    46226         red
# 405      25       ford     door  1984  salvage insurance    41577       white
# 545       0        gmc     door  1993  salvage insurance        0  light blue
# 322       0       ford  chassis  1994  salvage insurance        0       green
# 362      25       ford   pickup  1994  salvage insurance   206162       white
# ...     ...        ...      ...   ...                ...      ...         ...
# 1676  23400       ford   fusion  2020      clean vehicle     2452        gray
# 1642  20600       ford   fusion  2020      clean vehicle    17858       black
# 206      25  chevrolet   vehicl  2020  salvage insurance     7232       black
# 1640  27000       ford  mustang  2020      clean vehicle    12748         red
# 1638  20000       ford   fusion  2020      clean vehicle    23984      silver
#
# ...

# %%
df.sort_values(by='price')
# Out:
#       price          brand       model  year       title_status  mileage  \
# 455       0      chevrolet        door  2006  salvage insurance   268040
# 421       0            bmw        door  2000  salvage insurance   216657
# 420       0           audi        door  2005  salvage insurance   181896
# 419       0            kia       wagon  2008  salvage insurance   148463
# 293       0      chevrolet      pickup  1998  salvage insurance   258631
# ...     ...            ...         ...   ...                ...      ...
# 1215  65500           ford         srw  2019      clean vehicle     6500
# 277   67000          dodge  challenger  2019      clean vehicle    10944
# 1336  70000           ford         drw  2019      clean vehicle     9643
# 1340  74000           ford         drw  2019      clean vehicle    10536
# 502   84900  mercedes-benz    sl-class  2017      clean vehicle    25302
#
#          color                  vin        lot       state country  \
# ...

# %%
df['rank'] = df['price'].rank()

# %%
df.sort_values(by='price')
# Out:
#       price          brand       model  year       title_status  mileage  \
# 455       0      chevrolet        door  2006  salvage insurance   268040
# 421       0            bmw        door  2000  salvage insurance   216657
# 420       0           audi        door  2005  salvage insurance   181896
# 419       0            kia       wagon  2008  salvage insurance   148463
# 293       0      chevrolet      pickup  1998  salvage insurance   258631
# ...     ...            ...         ...   ...                ...      ...
# 1215  65500           ford         srw  2019      clean vehicle     6500
# 277   67000          dodge  challenger  2019      clean vehicle    10944
# 1336  70000           ford         drw  2019      clean vehicle     9643
# 1340  74000           ford         drw  2019      clean vehicle    10536
# 502   84900  mercedes-benz    sl-class  2017      clean vehicle    25302
#
#          color                  vin        lot       state country  \
# ...

# %%
df['price'].idxmax()
df.iloc[df['price'].idxmax()]
# Out:
# price                         84900
# brand                 mercedes-benz
# model                      sl-class
# year                           2017
# title_status          clean vehicle
# mileage                       25302
# color                        silver
# vin               wddjk7ea3hf044968
# lot                       167607883
# state                       florida
# country                         usa
# condition               2 days left
# rank                         2499.0
# Name: 502, dtype: object

# %%
df.head()
# Out:
#    price      brand    model  year   title_status  mileage   color  \
# 0   6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1   2899       ford       se  2011  clean vehicle   190552  silver
# 2   5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3  25000       ford     door  2014  clean vehicle    64146    blue
# 4  27700  chevrolet     1500  2018  clean vehicle     6654     red
#
#                    vin        lot       state country      condition    rank
# 0    jtezu11f88k007763  159348797  new jersey     usa   10 days left   381.0
# 1    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left   156.0
# 2    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left   326.5
# 3    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left  1832.5
# 4    3gcpcrec2jg473991  167763266     florida     usa  22 hours left  2005.0

# %%
idxkm = df['mileage'].idxmax()
df.iloc[idxkm]
# Out:
# price                          1025
# brand                     peterbilt
# model                         truck
# year                           2010
# title_status      salvage insurance
# mileage                     1017936
# color                        color:
# vin               1xp7d49x0ad793710
# lot                       167529842
# state                       georgia
# country                         usa
# condition             17 hours left
# rank                           94.5
# Name: 528, dtype: object

# %%
df['brand'].unique()
# Out:
# array(['toyota', 'ford', 'dodge', 'chevrolet', 'gmc', 'chrysler', 'kia',
#        'buick', 'infiniti', 'mercedes-benz', 'jeep', 'bmw', 'cadillac',
#        'hyundai', 'mazda', 'honda', 'heartland', 'jaguar', 'acura',
#        'harley-davidson', 'audi', 'lincoln', 'lexus', 'nissan', 'land',
#        'maserati', 'peterbilt', 'ram'], dtype=object)

# %%
df['brand'].value_counts()
# Out:
# brand
# ford               1235
# dodge               432
# nissan              312
# chevrolet           297
# gmc                  42
# jeep                 30
# chrysler             18
# bmw                  17
# hyundai              15
# buick                13
# kia                  13
# infiniti             12
# honda                12
# mercedes-benz        10
# cadillac             10
# heartland             5
# audi                  4
# land                  4
# peterbilt             4
# acura                 3
# mazda                 2
# lexus                 2
# lincoln               2
# toyota                1
# harley-davidson       1
# jaguar                1
# maserati              1
# ram                   1
# Name: count, dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#             price      year   mileage       lot      rank
# price    1.000000  0.418274 -0.400838  0.159369  0.950057
# year     0.418274  1.000000 -0.594686  0.164582  0.459794
# mileage -0.400838 -0.594686  1.000000 -0.130475 -0.439376
# lot      0.159369  0.164582 -0.130475  1.000000  0.174547
# rank     0.950057  0.459794 -0.439376  0.174547  1.000000

# %%
df.describe()
# Out:
#               price         year       mileage           lot         rank
# count   2499.000000  2499.000000  2.499000e+03  2.499000e+03  2499.000000
# mean   18767.671469  2016.714286  5.229869e+04  1.676914e+08  1250.000000
# std    12116.094936     3.442656  5.970552e+04  2.038772e+05   721.537031
# min        0.000000  1973.000000  0.000000e+00  1.593488e+08    22.000000
# 25%    10200.000000  2016.000000  2.146650e+04  1.676253e+08   623.500000
# 50%    16900.000000  2018.000000  3.536500e+04  1.677451e+08  1251.500000
# 75%    25555.500000  2019.000000  6.347250e+04  1.677798e+08  1874.500000
# max    84900.000000  2020.000000  1.017936e+06  1.678055e+08  2499.000000

# %%
df[df.brand=='ford']
# Out:
#       price brand   model  year   title_status  mileage     color  \
# 1      2899  ford      se  2011  clean vehicle   190552    silver
# 3     25000  ford    door  2014  clean vehicle    64146      blue
# 9      5250  ford     mpv  2017  clean vehicle    63418     black
# 14    20700  ford    door  2013  clean vehicle   100757     black
# 18     5210  ford     mpv  2017  clean vehicle    35714     white
# ...     ...   ...     ...   ...            ...      ...       ...
# 2199  13800  ford  fusion  2019  clean vehicle    29345     white
# 2200  56000  ford     srw  2018  clean vehicle    25371     black
# 2201  13800  ford  fusion  2019  clean vehicle    30054    silver
# 2202  45800  ford     srw  2018  clean vehicle    11173     white
# 2203  13800  ford  fusion  2019  clean vehicle    30902  no_color
#
#                       vin        lot           state country      condition  \
# 1       2fmdk3gc4bbb02217  166951262       tennessee     usa    6 days left
# ...

# %%
df_nissan = df[df.brand=='nissan']

# %%
df_nissan.loc[df_nissan['price'].idxmax()]
# Out:
# price                         36300
# brand                        nissan
# model                            xd
# year                           2017
# title_status          clean vehicle
# mileage                       16224
# color                         white
# vin               1n6ba1f46hn535299
# lot                       167753308
# state                      virginia
# country                         usa
# condition             21 hours left
# rank                         2305.5
# Name: 2375, dtype: object

# %%
df_nissan.loc[df_nissan['price'].idxmin()]
# Out:
# price                           375
# brand                        nissan
# model                          door
# year                           2017
# title_status      salvage insurance
# mileage                           1
# color                           red
# vin               3n1ce2cp0hl360793
# lot                       167619908
# state                north carolina
# country                         usa
# condition               2 days left
# rank                           74.0
# Name: 2417, dtype: object

# %%
df_chevrolet = df[df.brand=='chevrolet']
df_chevrolet['model'].value_counts()
# Out:
# model
# door         99
# 1500         38
# equinox      18
# van          17
# suburban     16
# colorado     12
# impala       12
# malibu       12
# tahoe         9
# trax          8
# 2500          8
# camaro        6
# traverse      6
# pickup        6
# 3500          4
# corvette      4
# ld            3
# coupe         3
# passenger     3
# cutaway       2
# volt          2
# sonic         2
# cruze         2
# pk            1
# vehicl        1
# cab           1
# utility       1
# spark         1
# Name: count, dtype: int64

# %%
df['price'].corr(df['year'])
# Out:
# np.float64(0.4182735684917942)

# %%
df.corrwith(df['price'], numeric_only=True)
# Out:
# price      1.000000
# year       0.418274
# mileage   -0.400838
# lot        0.159369
# rank       0.950057
# dtype: float64

# %%
kia_hyundai = df[(df.brand=='kia') | (df.brand=='hyundai')]
kia_hyundai.head()
# Out:
#      price    brand    model  year   title_status  mileage   color  \
# 16    5200      kia    forte  2018  clean vehicle    46194    blue
# 21    7300      kia    forte  2018  clean vehicle    38823   black
# 26   21500      kia  sorento  2020  clean vehicle    11451    blue
# 287   8200  hyundai     door  2017  clean vehicle    56690   white
# 288   3000      kia     door  2013  clean vehicle    97142  silver
#
#                      vin        lot           state country     condition  \
# 16     3kpfk4a77je198723  167801757  north carolina     usa   2 days left
# 21     3kpfl4a79je272611  167801773  north carolina     usa   2 days left
# 26     5xypg4a59lg616029  167801828  north carolina     usa   2 days left
# 287    5npd84lf6hh128808  167117726     connecticut     usa  5 hours left
# 288    knagm4a75d5378293  167552545        missouri     usa   9 days left
#
#        rank
# 16    319.0
# 21    440.0
# 26   1566.5
# 287   506.5
# 288   168.0

# %%
malibu_impala = df[(df.brand=='chevrolet') & ((df.model=='malibu') | (df.model=='impala'))]
malibu_impala
# Out:
#      price      brand   model  year   title_status  mileage     color  \
# 8    14600  chevrolet  malibu  2018  clean vehicle     9371    silver
# 47   19000  chevrolet  malibu  2017  clean vehicle    18414     white
# 107  18003  chevrolet  malibu  2017  clean vehicle    19117  no_color
# 204   6000  chevrolet  malibu  2018  clean vehicle    42090      gray
# 266  17100  chevrolet  malibu  2019  clean vehicle    15780     white
# 278  18900  chevrolet  impala  2019  clean vehicle    27601     white
# 281  18300  chevrolet  impala  2019  clean vehicle    25809     black
# 569  13500  chevrolet  impala  2018  clean vehicle    53194     white
# 647   9000  chevrolet  malibu  2016  clean vehicle    67527      gray
# 677  13700  chevrolet  malibu  2019  clean vehicle    47282    silver
# 686  12300  chevrolet  malibu  2018  clean vehicle    53599     black
# 688  13600  chevrolet  malibu  2018  clean vehicle    36047     white
# ...

# %%
df_ford = df[df.brand=='ford']
df_ford
# Out:
#       price brand   model  year   title_status  mileage     color  \
# 1      2899  ford      se  2011  clean vehicle   190552    silver
# 3     25000  ford    door  2014  clean vehicle    64146      blue
# 9      5250  ford     mpv  2017  clean vehicle    63418     black
# 14    20700  ford    door  2013  clean vehicle   100757     black
# 18     5210  ford     mpv  2017  clean vehicle    35714     white
# ...     ...   ...     ...   ...            ...      ...       ...
# 2199  13800  ford  fusion  2019  clean vehicle    29345     white
# 2200  56000  ford     srw  2018  clean vehicle    25371     black
# 2201  13800  ford  fusion  2019  clean vehicle    30054    silver
# 2202  45800  ford     srw  2018  clean vehicle    11173     white
# 2203  13800  ford  fusion  2019  clean vehicle    30902  no_color
#
#                       vin        lot           state country      condition  \
# 1       2fmdk3gc4bbb02217  166951262       tennessee     usa    6 days left
# ...

# %%
df_mustang = df_ford[df_ford.model=='mustang']
df_mustang
# Out:
#       price brand    model  year   title_status  mileage     color  \
# 632   25511  ford  mustang  2019  clean vehicle    11342      gray
# 1224  21900  ford  mustang  2018  clean vehicle    29748       red
# 1266  22000  ford  mustang  2018  clean vehicle     6248       red
# 1267  38200  ford  mustang  2019  clean vehicle      878     green
# 1269  35000  ford  mustang  2018  clean vehicle     2042      blue
# 1298  49000  ford  mustang  2017  clean vehicle     2205     black
# 1314  21600  ford  mustang  2019  clean vehicle    29457      gray
# 1316  21500  ford  mustang  2019  clean vehicle    29096       red
# 1352  35100  ford  mustang  2019  clean vehicle    10099       red
# 1354  34100  ford  mustang  2019  clean vehicle    10483     white
# 1356  34100  ford  mustang  2019  clean vehicle    10167       red
# 1376  21800  ford  mustang  2018  clean vehicle    16079  no_color
# 1377  18800  ford  mustang  2018  clean vehicle    41147     white
# ...

# %%
df2018mustang = df_mustang[df_mustang.year>=2018]
df2018mustang.price.mean()
# Out:
# np.float64(24837.444444444445)

# %%
df_mustang.describe()
# Out:
#               price         year       mileage           lot         rank
# count     29.000000    29.000000     29.000000  2.900000e+01    29.000000
# mean   25841.758621  2018.517241  21551.931034  1.677386e+08  1791.189655
# std     7781.073538     0.784706  12153.315994  7.464566e+04   390.396191
# min    15500.000000  2016.000000    878.000000  1.675552e+08  1091.000000
# 25%    20500.000000  2018.000000  11342.000000  1.677355e+08  1515.500000
# 50%    22000.000000  2019.000000  25011.000000  1.677637e+08  1598.500000
# 75%    29800.000000  2019.000000  31561.000000  1.677824e+08  2111.000000
# max    49000.000000  2020.000000  41147.000000  1.678018e+08  2439.500000

# %%
df_ford.year.value_counts().idxmax()
# Out:
# np.int64(2019)
