# %%
import pandas as pd

# %%
import numpy as np

# %%
emails = {"botir" : "botir123@gmail.com", "nurbek":"nurbek456@gmail.ru", "ali": "ali789@gmail.uz", "baxrom":"baxrom12@gmail.com"}
usurnames = {"botir" : "botirov", "nurbek":"nurbekov", "ali": "aliyev", "baxrom":"baxromov"}

data = {
    "username" : usurnames,
    "email" : emails
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#         username               email
# botir    botirov  botir123@gmail.com
# nurbek  nurbekov  nurbek456@gmail.ru
# ali       aliyev     ali789@gmail.uz
# baxrom  baxromov  baxrom12@gmail.com

# %%
df.index
# Out:
# Index(['botir', 'nurbek', 'ali', 'baxrom'], dtype='object')

# %%
data2 = {
    "username" : {"davlat":"davlatbek", "umid":"umidjon", "shahzod":"shakh"},
    "email" : {"davlat":"davlat@gmail.com","umid": "umid@gmail.com","shahzod": "shahzod@gmail.com"}
}

# %%
data2
# Out:
# {'username': {'davlat': 'davlatbek', 'umid': 'umidjon', 'shahzod': 'shakh'},
#  'email': {'davlat': 'davlat@gmail.com',
#   'umid': 'umid@gmail.com',
#   'shahzod': 'shahzod@gmail.com'}}

# %%
df2 = pd.DataFrame(data2)
df2
# Out:
#           username              email
# davlat   davlatbek   davlat@gmail.com
# umid       umidjon     umid@gmail.com
# shahzod      shakh  shahzod@gmail.com

# %%
df3 = pd.concat([df, df2])
df3
# Out:
#           username               email
# botir      botirov  botir123@gmail.com
# nurbek    nurbekov  nurbek456@gmail.ru
# ali         aliyev     ali789@gmail.uz
# baxrom    baxromov  baxrom12@gmail.com
# davlat   davlatbek    davlat@gmail.com
# umid       umidjon      umid@gmail.com
# shahzod      shakh   shahzod@gmail.com

# %%
newind = pd.Index(["botir", "abc", "dfg"])
newind
# Out:
# Index(['botir', 'abc', 'dfg'], dtype='object')

# %%
newind.isin(df3.index)
# Out:
# array([ True, False, False])

# %%
df3.index.difference(newind)
# Out:
# Index(['ali', 'baxrom', 'davlat', 'nurbek', 'shahzod', 'umid'], dtype='object')

# %%
newind.difference(df3.index)
# Out:
# Index(['abc', 'dfg'], dtype='object')

# %%
df3.index.union(newind)
# Out:
# Index(['abc', 'ali', 'baxrom', 'botir', 'davlat', 'dfg', 'nurbek', 'shahzod',
#        'umid'],
#       dtype='object')
