# %%
import pandas as pd
import numpy as np

# %%
from pandas  import Series, DataFrame as df

# %%
cars_dict = {"Nexia 2" : 5000, "Gentra" : 15500, "Cobalt" : 14000, "Damas" : 8000, "Nexia 3" : 9000}

# %%
cars1 = pd.Series(cars_dict)

# %%
cars1
# Out:
# Nexia 2     5000
# Gentra     15500
# Cobalt     14000
# Damas       8000
# Nexia 3     9000
# dtype: int64

# %%
cars1.name = "moshinalar"

# %%
cars1.index.name = "Nomlari"

# %%
cars1
# Out:
# Nomlari
# Nexia 2     5000
# Gentra     15500
# Cobalt     14000
# Damas       8000
# Nexia 3     9000
# Name: moshinalar, dtype: int64

# %%
new_price = Series({"Nexia 2" : 1000, "Lacetti" : 4500, "Malibu" : 20000, "Damas" : 1000, "Nexia 3" : 500, "Cobalt" : 400})

# %%
new_price
# Out:
# Nexia 2     1000
# Lacetti     4500
# Malibu     20000
# Damas       1000
# Nexia 3      500
# Cobalt       400
# dtype: int64

# %%
cars1+new_price
# Out:
# Cobalt     14400.0
# Damas       9000.0
# Gentra         NaN
# Lacetti        NaN
# Malibu         NaN
# Nexia 2     6000.0
# Nexia 3     9500.0
# dtype: float64

# %%
cars2 = cars1 + new_price

# %%
cars2
# Out:
# Cobalt     14400.0
# Damas       9000.0
# Gentra         NaN
# Lacetti        NaN
# Malibu         NaN
# Nexia 2     6000.0
# Nexia 3     9500.0
# dtype: float64

# %%
cars2.isnull()
# Out:
# Cobalt     False
# Damas      False
# Gentra      True
# Lacetti     True
# Malibu      True
# Nexia 2    False
# Nexia 3    False
# dtype: bool

# %%
cars2.notnull()
# Out:
# Cobalt      True
# Damas       True
# Gentra     False
# Lacetti    False
# Malibu     False
# Nexia 2     True
# Nexia 3     True
# dtype: bool

# %%
cars2.hasnans # NaN qiymatlar bor (True) yo'qligi (False)
# Out:
# True

# %%
cars2.is_unique # qiymatlar takrorlanmas ekanini tekshirish
# Out:
# False

# %%
cars2.shape # Series hajmi
# Out:
# (7,)

# %%
cars2.size # Series hajmi
# Out:
# 7

# %%
cars2.iloc[6] # ma'lumotlarga indeks tartib raqami bo'yicha murojaat qilish
# Out:
# np.float64(9500.0)

# %%
cars2['Nexia 2'] # ma'lumotlarga indeks bo'yicha murojaat qilish
# Out:
# np.float64(6000.0)

# %%
cars2.loc['Nexia 2'] # ma'lumotlarga indeks bo'yicha murojaat qilish
# Out:
# np.float64(6000.0)

# %%
cars2.max() # max qiymat
# Out:
# 14400.0

# %%
cars2.min() # min qiymat
# Out:
# 6000.0

# %%
cars2.mean() # o'rtacha qiymat
# Out:
# np.float64(9725.0)

# %%
cars_3 = Series({"BMW" : 50000, "Mers" : "oltmishming, "Tico" : "beshuz"})
# Out:
#   File "/tmp/ipykernel_4722/2992345888.py", line 1
#     cars_3 = Series({"BMW" : 50000, "Mers" : "oltmishming, "Tico" : "beshuz"})
#                                                                            ^
# SyntaxError: unterminated string literal (detected at line 1)
